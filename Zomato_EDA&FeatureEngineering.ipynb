# %% [markdown]
# ## Zomato Dataset Exploratory Data Analysis

# %% [markdown]
# #### Importing the libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#using matplotlib inline so that any visualization gets displayed here itself
# %matplotlib inline

# %% [markdown]
# #### Importing the Zomato dataset:

# %%
df=pd.read_csv('Zomato\zomato.csv', encoding= 'latin-1')
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %% [markdown]
# #### The number of rows (observations) and the number of columns (variables):

# %%
df.shape
# Out:
# (9551, 21)

# %% [markdown]
# #### Checking the columns(variables):

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# #### Understanding more about dataset:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# #### The basic measures of descriptive statistics, using describe function(shows only integer features):

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %% [markdown]
# ## In Data Analysis,
# 1. Check Missing Values
# 2. Explore about the numerical variables
# 3. Explore about the categorical variables
# 4. Find Relationship between features

# %% [markdown]
# #### Finding missing values:

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# #### Checking missing values using heat map:

# %%
#temp variables iterate through col & if specific feature is null and sum > 0
[features for features in df.columns if df[features].isnull().sum()>0]
# Out:
# ['Cuisines']

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=(12,6)
sns.heatmap(df.isnull(), yticklabels=False, cbar=False , cmap='viridis')
plt.show()

# %% [markdown]
# #### Reading country code data set which is in xlsx format:

# %%
df_country=pd.read_excel('Zomato\Country-Code.xlsx')
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %% [markdown]
# #### Checking the columns(variables):

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %% [markdown]
# #### Combining two dataframes w.r.t country code:

# %%
final_df=pd.merge(df, df_country, on='Country Code', how='left')
final_df.head(2)
#use concat w.r.t to this diff parameters you have to use it there
# Out:
#    Restaurant ID   Restaurant Name  Country Code         City  \
# 0        6317637  Le Petit Souffle           162  Makati City
# 1        6304287  Izakaya Kikufuji           162  Makati City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
#
#                                     Locality Verbose   Longitude   Latitude  \
# 0  Century City Mall, Poblacion, Makati City, Mak...  121.027535  14.565443
# 1  Little Tokyo, Legaspi Village, Makati City, Ma...  121.014101  14.553708
#
#                      Cuisines  ...  Has Table booking Has Online delivery  \
# 0  French, Japanese, Desserts  ...                Yes                  No
# 1                    Japanese  ...                Yes                  No
#
# ...

# %% [markdown]
# #### Checking Data Types:

# %%
final_df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# Country                  object
# dtype: object

# %% [markdown]
# #### Checking the columns(variables):

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# #### Finding different countries and number of records of those specific countries:

# %%
final_df.Country.value_counts()
# Out:
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: Country, dtype: int64

# %% [markdown]
# #### Finding all the countries name w.r.t to specific records:

# %%
country_names=final_df.Country.value_counts().index
country_names
# Out:
# Index(['India', 'United States', 'United Kingdom', 'Brazil', 'UAE',
#        'South Africa', 'New Zealand', 'Turkey', 'Australia', 'Phillipines',
#        'Indonesia', 'Singapore', 'Qatar', 'Sri Lanka', 'Canada'],
#       dtype='object')

# %% [markdown]
# #### Finding the total number of records for that particular country name:

# %%
number_of_records=final_df.Country.value_counts().values
number_of_records
# Out:
# array([8652,  434,   80,   60,   60,   60,   40,   34,   24,   22,   21,
#          20,   20,   20,    4], dtype=int64)

# %% [markdown]
# #### Creating a pie chart of top 3 countries using Zomato:

# %%
plt.figure(figsize=(5,5))
plt.pie(number_of_records[0:3], labels=country_names[0:3], autopct='%1.2f%%')
plt.show()

# %% [markdown]
# ### Observations:
#
# 1. 94.39% of zomato partnered restaurants are in India, 4.73% in US and 0.87% in UK.
#
# 2. Zomato maximum records or transaction are from India after that USA and then UK.

# %% [markdown]
# #### Checking the columns(variables):

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %% [markdown]
# #### Creating a dataframe having features 'Aggregate rating', 'Rating color', 'Rating text' and 'Rating count':

# %%
#using reset_index, resetting the index of each row.
#variables would play imp role.
ratings=final_df.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns={0:'Rating Count'})
ratings
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# ### Conclusion:
# Around 2148 records have 0 ratings.

# %% [markdown]
# ### Observations:
# 1. When rating is between 4.5 to 4.9 ---> Excellent
# 2. When rating is between 4.0 to 4.4 ---> Very Good
# 3. When rating is between 3.5 to 3.9 ---> Good
# 4. When rating is between 3.0 to 3.4 ---> Average
# 5. When rating is between 2.5 to 2.9 ---> Average
# 6. When rating is between 1.8 to 2.4 ---> Poor

# %% [markdown]
# #### Making a bar plot showing relation between rating text and rating count:

# %%
#sns.barplot(list(ratings['Rating text']), list(ratings['Rating Count']))
sns.barplot(x='Rating text', y='Rating Count', data=ratings)
plt.show()

# %% [markdown]
# #### Making a bar plot showing relation between aggregate rating and rating count:

# %%
#Params=parameters
#Looks like a gaussian curve

import matplotlib
matplotlib.rcParams['figure.figsize']=(12,6)
sns.barplot(x='Aggregate rating', y='Rating Count', data=ratings)
plt.show()

# %% [markdown]
# #### Modifying the bar plot, color the aggregate rating as color that is given (using hue= rating color):

# %%
#mapping the color using palette
import matplotlib
matplotlib.rcParams['figure.figsize']=(12,6)
sns.barplot(x='Aggregate rating', y='Rating Count',hue='Rating color', data=ratings, palette=['BLUE', 'red', 'orange', 'yellow', 'green','green'])
plt.show()

# %% [markdown]
# ### Observation:
# 1. Not Rated count is very high.
# 2. Maximum number of ratings are between 2.5 and 3.4

# %%
#suppose a person has rated but we have some missing values now. 
#We can use the values between 2.5 to 3.4 as an average because max. number of ratings are between 2.5 to 3.4.

# %% [markdown]
# #### Making count plot w.r.t rating color:

# %%
sns.countplot(x='Rating color', data=ratings, palette=['BLUE', 'red', 'orange', 'yellow', 'green','green'])
plt.show()

# %%
ratings
#In the above count plot, on y-axis, the count is the frequency present in the below dataframe
# Out:
#     Aggregate rating Rating color Rating text  Rating Count
# 0                0.0        White   Not rated          2148
# 1                1.8          Red        Poor             1
# 2                1.9          Red        Poor             2
# 3                2.0          Red        Poor             7
# 4                2.1          Red        Poor            15
# 5                2.2          Red        Poor            27
# 6                2.3          Red        Poor            47
# 7                2.4          Red        Poor            87
# 8                2.5       Orange     Average           110
# 9                2.6       Orange     Average           191
# 10               2.7       Orange     Average           250
# 11               2.8       Orange     Average           315
# 12               2.9       Orange     Average           381
# 13               3.0       Orange     Average           468
# 14               3.1       Orange     Average           519
# ...

# %% [markdown]
# #### Combining two dataframes w.r.t country code:

# %%
final_df=pd.merge(df, df_country, on='Country Code', how='left')
final_df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# #### Sorting the dataframe(final_df) by "Aggregate rating":

# %%
sorted_final_df=final_df.sort_values(by='Aggregate rating')
sorted_final_df
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 6615       18446486               LSK Express             1  New Delhi
# 1994       18393709                Apni Rasoi             1    Gurgaon
# 1995       18421493     Bala Ji Sweets Corner             1    Gurgaon
# 1996       18464628                   Barista             1    Gurgaon
# 1997       18398590           Biryani Express             1    Gurgaon
# ...             ...                       ...           ...        ...
# 9514        5800176          Ministry of Crab           191    Colombo
# 39          6600427                Coco Bambu            30  Brasí_lia
# 324        17500759   Ingleside Village Pizza           216      Macon
# 580         5703500              Punjab Grill           214  Abu Dhabi
# 507        17095098  Mazzaro's Italian Market           216  Tampa Bay
#
#                                                 Address  \
# 6615               4a/57, Old Rajinder Nagar, New Delhi
# ...

# %% [markdown]
# #### Extracting the unique values of Country column:

# %%
final_df['Country'].unique()
# Out:
# array(['Phillipines', 'Brazil', 'United States', 'Australia', 'Canada',
#        'Singapore', 'UAE', 'India', 'Indonesia', 'New Zealand',
#        'United Kingdom', 'Qatar', 'South Africa', 'Sri Lanka', 'Turkey'],
#       dtype=object)

# %% [markdown]
# #### Finding the country names that has given 0 ratings:

# %%
Zero_rating_values=[0.0]
Zero_rating_df=final_df[final_df['Aggregate rating'].isin(Zero_rating_values)]
Zero_rating_df['Country'].value_counts()
# Out:
# India             2139
# Brazil               5
# United States        3
# United Kingdom       1
# Name: Country, dtype: int64

# %%
#In a single line
final_df[final_df['Aggregate rating'].isin(Zero_rating_values)]['Country'].value_counts()
# Out:
# India             2139
# Brazil               5
# United States        3
# United Kingdom       1
# Name: Country, dtype: int64

# %%
#Using parameter rating color, we can find the country names that has given 0 ratings.
final_df[final_df['Rating color']=='White']['Country'].value_counts()
# Out:
# India             2139
# Brazil               5
# United States        3
# United Kingdom       1
# Name: Country, dtype: int64

# %%
#or using group by and size
final_df[final_df['Rating color']=='White'].groupby('Country').size().reset_index()
# Out:
#           Country     0
# 0          Brazil     5
# 1           India  2139
# 2  United Kingdom     1
# 3   United States     3

# %%
#using head 
final_df.groupby(['Aggregate rating','Country']).size().reset_index().head(5)
# Out:
#    Aggregate rating         Country     0
# 0               0.0          Brazil     5
# 1               0.0           India  2139
# 2               0.0  United Kingdom     1
# 3               0.0   United States     3
# 4               1.8           India     1

# %% [markdown]
# ### Observation:
# 1. Maximum number of zero ratings are from Indian customers

# %% [markdown]
# #### Finding out which currency is used by which country:

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.groupby(['Country','Currency']).size().reset_index()
# Out:
#            Country                Currency     0
# 0        Australia               Dollar($)    24
# 1           Brazil      Brazilian Real(R$)    60
# 2           Canada               Dollar($)     4
# 3            India      Indian Rupees(Rs.)  8652
# 4        Indonesia  Indonesian Rupiah(IDR)    21
# 5      New Zealand           NewZealand($)    40
# 6      Phillipines        Botswana Pula(P)    22
# 7            Qatar         Qatari Rial(QR)    20
# 8        Singapore               Dollar($)    20
# 9     South Africa                 Rand(R)    60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)    20
# 11          Turkey        Turkish Lira(TL)    34
# 12             UAE      Emirati Diram(AED)    60
# 13  United Kingdom              Pounds(£)    80
# 14   United States               Dollar($)   434

# %%
#long query 
final_df[['Country', 'Currency']].groupby(['Country', 'Currency']).size().reset_index()
# Out:
#            Country                Currency     0
# 0        Australia               Dollar($)    24
# 1           Brazil      Brazilian Real(R$)    60
# 2           Canada               Dollar($)     4
# 3            India      Indian Rupees(Rs.)  8652
# 4        Indonesia  Indonesian Rupiah(IDR)    21
# 5      New Zealand           NewZealand($)    40
# 6      Phillipines        Botswana Pula(P)    22
# 7            Qatar         Qatari Rial(QR)    20
# 8        Singapore               Dollar($)    20
# 9     South Africa                 Rand(R)    60
# 10       Sri Lanka   Sri Lankan Rupee(LKR)    20
# 11          Turkey        Turkish Lira(TL)    34
# 12             UAE      Emirati Diram(AED)    60
# 13  United Kingdom              Pounds(£)    80
# 14   United States               Dollar($)   434

# %% [markdown]
# #### Finding the countries that have online delivery option:

# %%
#final_df.groupby(['Country', 'Has Online delivery']).size().reset_index()
final_df[final_df['Has Online delivery']=='Yes'].groupby(['Country']).size().reset_index()
# Out:
#   Country     0
# 0   India  2423
# 1     UAE    28

# %%
final_df[final_df['Has Online delivery']=='Yes'].Country.value_counts()
# Out:
# India    2423
# UAE        28
# Name: Country, dtype: int64

# %%
final_df[final_df['Has Online delivery']=='Yes'].Country.value_counts().reset_index()
# Out:
#    index  Country
# 0  India     2423
# 1    UAE       28

# %%
final_df.groupby(['Country', 'Has Online delivery']).size().reset_index()
# Out:
#            Country Has Online delivery     0
# 0        Australia                  No    24
# 1           Brazil                  No    60
# 2           Canada                  No     4
# 3            India                  No  6229
# 4            India                 Yes  2423
# 5        Indonesia                  No    21
# 6      New Zealand                  No    40
# 7      Phillipines                  No    22
# 8            Qatar                  No    20
# 9        Singapore                  No    20
# 10    South Africa                  No    60
# 11       Sri Lanka                  No    20
# 12          Turkey                  No    34
# 13             UAE                  No    32
# 14             UAE                 Yes    28
# 15  United Kingdom                  No    80
# 16   United States                  No   434

# %% [markdown]
# ### Observation:
# 1. Online deliveries are available in India and UAE
# 2. In India and UAE, some areas online delivery is not there

# %% [markdown]
# #### Create a pie chart for cities distribution:

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df['City'].value_counts().head(5).reset_index()
# Out:
#        index  City
# 0  New Delhi  5473
# 1    Gurgaon  1118
# 2      Noida  1080
# 3  Faridabad   251
# 4  Ghaziabad    25

# %%
final_df['City'].value_counts()
# Out:
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: City, Length: 141, dtype: int64

# %%
list(final_df['City'].unique())
# Out:
# ['Makati City',
#  'Mandaluyong City',
#  'Pasay City',
#  'Pasig City',
#  'Quezon City',
#  'San Juan City',
#  'Santa Rosa',
#  'Tagaytay City',
#  'Taguig City',
#  'Brasí_lia',
#  'Rio de Janeiro',
#  'Sí£o Paulo',
#  'Albany',
#  'Armidale',
#  'Athens',
#  'Augusta',
#  'Balingup',
#  'Beechworth',
#  'Boise',
#  'Cedar Rapids/Iowa City',
#  'Chatham-Kent',
#  'Clatskanie',
#  'Cochrane',
#  'Columbus',
#  'Consort',
#  'Dalton',
#  'Davenport',
#  'Des Moines',
#  'Dicky Beach',
#  'Dubuque',
#  'East Ballina',
#  'Fernley',
#  'Flaxton',
#  'Forrest',
#  'Gainesville',
#  'Hepburn Springs',
#  'Huskisson',
#  'Inverloch',
#  'Lakes Entrance',
#  'Lakeview',
#  'Lincoln',
#  'Lorn',
#  'Macedon',
#  'Macon',
#  'Mayfield',
#  'Mc Millan',
#  'Middleton Beach',
#  'Miller',
#  'Monroe',
#  'Montville',
#  'Ojo Caliente',
#  'Orlando',
#  'Palm Cove',
#  'Paynesville',
#  'Penola',
#  'Pensacola',
#  'Phillip Island',
#  'Pocatello',
#  'Potrero',
#  'Princeton',
# ...

# %%
piedata=final_df['City'].value_counts().head(10)
piedata
# Out:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Bhubaneshwar      21
# Amritsar          21
# Ahmedabad         21
# Lucknow           21
# Guwahati          21
# Name: City, dtype: int64

# %%
plt.pie(list(final_df.City.value_counts()[0:5]),labels=list(final_df.City.value_counts()[0:5].keys()))
plt.show()

# %%
final_df.City.value_counts()
# Out:
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# Faridabad            251
# Ghaziabad             25
#                     ...
# Panchkula              1
# Mc Millan              1
# Mayfield               1
# Macedon                1
# Vineland Station       1
# Name: City, Length: 141, dtype: int64

# %%
plt.pie(list(final_df.City.value_counts()[0:5]),labels=list(final_df.City.value_counts()[0:5].keys()),autopct='%1.2f%%')
plt.show()

# %% [markdown]
# #### Finding top 10 cuisines:

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.Cuisines.value_counts().head(10).reset_index()
# Out:
#                             index  Cuisines
# 0                    North Indian       936
# 1           North Indian, Chinese       511
# 2                         Chinese       354
# 3                       Fast Food       354
# 4           North Indian, Mughlai       334
# 5                            Cafe       299
# 6                          Bakery       218
# 7  North Indian, Mughlai, Chinese       197
# 8                Bakery, Desserts       170
# 9                     Street Food       149

# %% [markdown]
# ### Observation:
# North Indian Cuisines has most number of records followed by Chinese Cuisines.
